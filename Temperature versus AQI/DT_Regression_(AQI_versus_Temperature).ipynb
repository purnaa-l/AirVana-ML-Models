# %% [markdown]
# <a href="https://colab.research.google.com/github/purnaa-l/MiniProject-ML-Models/blob/main/Temperature%20versus%20AQI/DT_Regression_(AQI_versus_Temperature).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Decision Tree Regression

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importing the dataset

# %%
df = pd.read_csv('IndianWeatherRepository.csv')
df.head()
# X = dataset.iloc[:, :-1].values
# y = dataset.iloc[:, -1].values
# Out:
#   country location_name          region  latitude  longitude      timezone  \
# 0   India    Ashoknagar  Madhya Pradesh     24.57      77.72  Asia/Kolkata
# 1   India        Raisen  Madhya Pradesh     23.33      77.80  Asia/Kolkata
# 2   India    Chhindwara  Madhya Pradesh     22.07      78.93  Asia/Kolkata
# 3   India         Betul  Madhya Pradesh     21.86      77.93  Asia/Kolkata
# 4   India   Hoshangabad  Madhya Pradesh     22.75      77.72  Asia/Kolkata
#
#    last_updated_epoch      last_updated  temperature_celsius  \
# 0          1693286100  2023-08-29 10:45                 27.5
# 1          1693286100  2023-08-29 10:45                 27.5
# 2          1693286100  2023-08-29 10:45                 26.3
# 3          1693286100  2023-08-29 10:45                 25.6
# 4          1693286100  2023-08-29 10:45                 27.2
#
#    temperature_fahrenheit  ... air_quality_PM2.5  air_quality_PM10  \
# 0                    81.5  ...              12.6              18.5
# ...

# %%
df = df[['temperature_celsius', 'air_quality_PM2.5', 'air_quality_PM10',
         'air_quality_us-epa-index', 'air_quality_gb-defra-index', 'region', 'last_updated']]

# %%
# Check missing values
print(df.isnull().sum())

# Drop rows with missing AQI or temperature
df.dropna(subset=['temperature_celsius', 'air_quality_PM2.5'], inplace=True)
# Out:
# temperature_celsius           0
# air_quality_PM2.5             0
# air_quality_PM10              0
# air_quality_us-epa-index      0
# air_quality_gb-defra-index    0
# region                        0
# last_updated                  0
# dtype: int64

# %%
df['hour'] = pd.to_datetime(df['last_updated']).dt.hour
df['day'] = pd.to_datetime(df['last_updated']).dt.dayofweek
df['region'] = df['region'].astype('category').cat.codes  # Convert categorical to numerical

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X = scaler.fit_transform(df[['temperature_celsius']])
y = df['air_quality_PM2.5']  # or any AQI index

# %%
df.head()
# Out:
#    temperature_celsius  air_quality_PM2.5  air_quality_PM10  \
# 0                 27.5               12.6              18.5
# 1                 27.5               10.7              14.2
# 2                 26.3               16.8              20.7
# 3                 25.6                4.9               6.6
# 4                 27.2               11.4              14.8
#
#    air_quality_us-epa-index  air_quality_gb-defra-index  region  \
# 0                         1                           2      19
# 1                         1                           1      19
# 2                         2                           2      19
# 3                         1                           1      19
# 4                         1                           1      19
#
#        last_updated  hour  day
# 0  2023-08-29 10:45    10    1
# 1  2023-08-29 10:45    10    1
# 2  2023-08-29 10:45    10    1
# 3  2023-08-29 10:45    10    1
# 4  2023-08-29 10:45    10    1

# %% [markdown]
# ## Splitting the dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# ## Training the Decision Tree Regression model on the Training set

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state = 0)
regressor.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=0)

# %% [markdown]
# ## Predicting the Test set results

# %%
y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
# print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

# %% [markdown]
# ## Evaluating the Model Performance

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.08311891404091698

# %% [markdown]
# The accuracy for Decision Tree is barely 0.083 which is not a reliable indicator at all.
